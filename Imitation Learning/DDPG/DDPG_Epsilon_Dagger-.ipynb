# %%
# Import helper libraries
from __future__ import print_function
from __future__ import unicode_literals
from __future__ import division
from __future__ import absolute_import
from future import standard_library
standard_library.install_aliases()  # NOQA
import argparse
import logging
import sys

#___________________________________________________________________
# Import scientific libraries

import numpy as np               # Numpy, a good library to deal with matrices in python.
import matplotlib.pyplot as plt  # Matplotlib, a good library for plotting in python.
from matplotlib import style
#___________________________________________________________________

import gym                       # Gym, a collection of RL environemnts.
gym.undo_logger_setup()  # NOQA
from gym import spaces
import gym.wrappers

from osim.env import ProstheticsEnv   # Open simulator (OSIM), an open source simnulation for biomechanical modeling.

#___________________________________________________________________



import tensorflow as tf                      # Tensorflow, a deep learning library.
import chainer                               # Chainer, a python-based deep learning framework. Chainerrl, a reinforcement learning library based on chainer framework.
from chainer import optimizers               # a collection of Neural Network optimizers.
from chainerrl.agents.ddpg import DDPG       # a DDPG agent
from chainerrl.agents.ddpg import DDPGModel  # a DDPG model, responsibles to combine the policy network and the value function network.
from chainerrl import explorers              # a collection of explores functions.
from chainerrl import misc                   # a collection of utility functions to manipulate the environemnts.
from chainerrl import policy                 # a policy network
from chainerrl import q_functions            # a value function network
from chainerrl import replay_buffer          # a Replay buffer to store a set of observations for the DDPG agent.


from ExpertAgents import ExpertDDPGAgent
style.use('ggplot')
# Out:
# /home/waleed_daud_wd/CondaEnvs/opensimEnv_V2/lib/python3.6/site-packages/gym/__init__.py:15: UserWarning: gym.undo_logger_setup is deprecated. gym no longer modifies the global logging configuration
#   warnings.warn("gym.undo_logger_setup is deprecated. gym no longer modifies the global logging configuration")

# %% [markdown]
# # A set of helper functions

# %%
# Helper's functions

def clip_action_filter(a):
    """ limit the an action value between the higest and lowest values in action space.
    Input: a
    Output: clipped action
    """
    return np.clip(a, action_space.low, action_space.high)

def reward_filter(r):
    """ Scale the reward value.
    Input: reward (r)
    Output: scaled reward
    """
    return r *1 #1e-2


def phi(obs):
    """ Convert the data type of the observation to float-32
    Input: observation (obs)
    Output:  the processed observation 
    """ 
    obs=np.array(obs)
    return obs.astype(np.float32)


def random_action():
    """ Generate a random action.
    Input: None
    Output:  a random action
    """ 
    a = action_space.sample()
    if isinstance(a, np.ndarray):
        a = a.astype(np.float32)
    return a


def make_env(test,render=False):
    
    """ Create an instance from "ProstheticEnv" environment
    Input: a boolean value to show if it's an agent training experiment or test experiment (test)
    Output:  "ProstheticEnv" environment (env)
    """ 
        
    env = ProstheticsEnv(visualize=render)
    # Use different random seeds for train and test envs
    env_seed = 2 ** 32 - 1 - seed if test else seed
    env.seed(env_seed)
    #if args.monitor:
        #env = gym.wrappers.Monitor(env, args.outdir)
    if isinstance(env.action_space, spaces.Box):
        misc.env_modifiers.make_action_filtered(env, clip_action_filter)
    if not test:
        misc.env_modifiers.make_reward_filtered(env, reward_filter)
    if render and not test:
        misc.env_modifiers.make_rendered(env)
    return env

# %%
seed=0

# %% [markdown]
# # Set up the environment.

# %%
# Setup the environment
env = make_env(test=False,render=False)
#timestep_limit = env.spec.tags.get('wrapper_config.TimeLimit.max_episode_steps')
obs_size = np.asarray(env.observation_space.shape).prod()
action_space = env.action_space
action_size = np.asarray(action_space.shape).prod()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: Could not seed environment <ProstheticsEnv<0>>

# %%
# Load the Expert agent.
load_expert_DDPG=ExpertDDPGAgent(path="Models/Model")
expert=load_expert_DDPG.load_agent()

# %%
number_of_episodes=50                     # Number of episodes
max_episode_length=1000                   # Max Number of timestep per episode.

# %%
# STEP 1: Generate Data using Expert.

returns = []
observations = []
actions = []
for i in range(number_of_episodes):
    print('episode: ', i)
    obs = env.reset()
    done = False
    G = 0.
    steps = 0
    while not done:
        action = expert.act(obs)                   # get an action from the expert policy.
        
        observations.append(obs)                  # save the observation
        actions.append(action)                   # save the action
        
        obs, r, done, _ = env.step(action)
        G += r
        steps += 1
        
        if steps % 100 == 0: print("%i/%i" % (steps, max_episode_length))
        if steps >= max_episode_length:
            break
    returns.append(G)
    
print('returns', returns)
print('mean return', np.mean(returns))
print('std of return', np.std(returns))
# Out:
# episode:  0
# episode:  1
# episode:  2
# episode:  3
# episode:  4
# episode:  5
# episode:  6
# episode:  7
# episode:  8
# episode:  9
# episode:  10
# episode:  11
# episode:  12
# episode:  13
# episode:  14
# episode:  15
# episode:  16
# episode:  17
# episode:  18
# episode:  19
# episode:  20
# episode:  21
# episode:  22
# episode:  23
# episode:  24
# episode:  25
# episode:  26
# episode:  27
# episode:  28
# episode:  29
# episode:  30
# episode:  31
# episode:  32
# episode:  33
# episode:  34
# episode:  35
# episode:  36
# episode:  37
# episode:  38
# episode:  39
# episode:  40
# episode:  41
# episode:  42
# episode:  43
# episode:  44
# episode:  45
# episode:  46
# episode:  47
# episode:  48
# episode:  49
# returns [58.46354079844838, 61.209274357659105, 59.327096861418624, 59.659493652465414, 60.409880098946, 59.370351321407675, 60.43158585851299, 61.19207583830714, 60.60999319150469, 60.124528563961235, 59.611840840975375, 58.98068901640656, 59.57588400054966, 63.84890689365919, 62.17163118973635, 59.14807169186517, 63.346016184291386, 62.73403969843032, 61.87969652731631, 59.078467999970826, 58.534270299219024, 60.956759059979376, 58.90308622789383, 59.96541693321168, 59.39713798189248, 60.4969761648768, 61.715464580890796, 61.43387342798505, 60.44843783223324, 59.54245868832388, 61.18341867346042, 60.50665732250426, 63.40873790061702, 62.380255886892826, 61.631415217681784, 60.3901380276277, 59.72543545137812, 59.02284063147045, 60.36389744736253, 58.849557970585266, 60.90870410530288, 60.6398992803315, 58.086289786507336, 61.69048053235774, 59.707211261652816, 61.9049380056037, 61.33508614895544, 61.00006484641085, 60.47099632687839, 58.821686787329256]
# mean return 60.49189314786498
# std of return 1.341077891142221

# %%
# pass observations, actions to the imitation learning algorithm.
obs_data = np.squeeze(np.array(observations))
act_data = np.squeeze(np.array(actions))

# %%
# Save the observations and actions of the expert policy
np.savetxt('Datasets/obs_data_naive_agent-epsilon.txt', obs_data, fmt='%f')
np.savetxt('Datasets/act_data_naive_agent-epsilon.txt', obs_data, fmt='%f')

# %% [markdown]
# # Build the policy network for the target agent.

# %%
#===========================================================================
# Build the policy network for the Target agent.
#===========================================================================

# %%
obs_dim = obs_data.shape[1]
act_dim = act_data.shape[1]

# %%
# Architecture of the target policy function

x = tf.placeholder(tf.float32, shape=[None, obs_dim])
yhot = tf.placeholder(tf.float32, shape=[None, act_dim])
    
h1 = tf.layers.dense(inputs=x, units=128, activation=tf.nn.relu)
h2 = tf.layers.dense(inputs=h1, units=64, activation=tf.nn.relu)
h3 = tf.layers.dense(inputs=h2, units=32, activation=tf.nn.relu)
yhat = tf.layers.dense(inputs=h3, units=act_dim, activation=None)
yhat= tf.squeeze(yhat)
    
loss = tf.reduce_mean(tf.square(yhot - yhat))
train = tf.train.AdamOptimizer().minimize(loss)

# Saver object to save the model
saver = tf.train.Saver()

# %% [markdown]
# # Train the target agent

# %%
# train The target network
number_of_iterations=100
batch_size = 25
epsilon = 0.9               # the initial epsilon value.
decay = 0.99                # epsilon decay factor.
min_epsilon = 0.1           # minimum epsilon value.

# Metrices

global_mean_G=[]

# %%
#___________ STEP 2: Train the target agent with the data that collected by the expert agent. ____________

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    # record return and std for plotting
    save_mean = []
    save_std = []
    save_train_size = []
    #loop for dagger alg
    
    for dagger_iter in range(number_of_iterations):
        print ('DAgger iteration ', dagger_iter)
        
        # train a policy by fitting the MLP
        for step in range(10000):
            batch_i = np.random.randint(0, obs_data.shape[0], size=batch_size)
            train.run(feed_dict={x: obs_data[batch_i, ], yhot: act_data[batch_i, ]})
            if (step % 1000 == 0):
                print ('opmization step ', step)
                print ('obj value is ', loss.eval(feed_dict={x:obs_data, yhot:act_data}) )        
                
        print('Optimization Finished!')
        
        # save naive agent
        saver.save(sess, 'NaiveAgents/Model_V1/naive_agent-epsilon',global_step=1000,write_meta_graph=False)


#______________________ STEP 3: Generate data using target Agent. ________________________
 
        
        
        returns = []
        naive_rewards=[]
        naive_observations = []
        naive_actions = []
        for i in range(number_of_episodes):
            print('iter', i)
            obs = env.reset()
            done = False
            G = 0.
            steps = 0
            while not done:
                obs=np.array(obs)
                action = yhat.eval(feed_dict={x:obs[None, :]})                # Sample an action using the target policy.
                naive_observations.append(obs)                                # Save the observation in "observations" list.
                naive_actions.append(action)                                  # Save the action in "actions" list.
                
                obs, r, done, _ = env.step(action)
                naive_rewards.append(r)
                G += r
                steps += 1   
                if steps % 100 == 0: print("%i/%i" % (steps, max_episode_length))
                if steps >= max_episode_length:
                    break
            returns.append(G)
            
        global_mean_G.append(np.mean(returns))
        print('mean return', np.mean(returns))
        print('std of return', np.std(returns))
            
            
        
            
#_________________________ STEP 4: Expert labeling ____________________________________
 
        corrected_act = []
        
        for i in range(len(naive_observations)):
            
            expert_action=expert.act(naive_observations[i])
            _,expert_reward,_,_=env.step(expert_action)
            
            naive_action=naive_actions[i]
            naive_reward=naive_rewards[i]
            
            random_number = np.random.random()
            if random_number > epsilon:                           # replace target action by the expert action with probability epsilon
                corrected_act.append(naive_action)
            else :                                                # replace target action by the expert action with probability 1-epsilon
                corrected_act.append(expert_action)
            
                
            
        # record training size
        train_size = obs_data.shape[0]
        
#_________________________ STEP 5: data aggregation _____________________________________
 
        obs_data = np.concatenate((obs_data, np.array(naive_observations)), axis=0)
        act_data = np.concatenate((act_data, np.squeeze(np.array(corrected_act))), axis=0)    # concatenate the the expert data ( observations + actions ) with target data.        
       
        
#________________________________________________________________ Decay epsilon value ___________________________________________________________________________________
        epsilon = max(min_epsilon, epsilon*decay)
#_________________________________________________________________________________________________________________________________________________________________________        
        # record mean return & std
        save_mean = np.append(save_mean, np.mean(returns))
        save_std = np.append(save_std, np.std(returns))
        save_train_size = np.append(save_train_size, train_size)
        
    dagger_results = {'means': save_mean, 'stds': save_std, 'train_size': save_train_size,}
    
    print ('DAgger iterations finished!')
# Out:
# DAgger iteration  0
# opmization step  0
# obj value is  2442887.0
# opmization step  1000
# obj value is  0.34040424
# opmization step  2000
# obj value is  0.29560244
# opmization step  3000
# obj value is  0.2447498
# opmization step  4000
# obj value is  0.19926743
# opmization step  5000
# obj value is  0.17195906
# opmization step  6000
# obj value is  0.15853922
# opmization step  7000
# obj value is  0.15577379
# opmization step  8000
# obj value is  0.15689792
# opmization step  9000
# obj value is  0.15698424
# Optimization Finished!
# iter 0
# 100/1000
# iter 1
# 100/1000
# iter 2
# 100/1000
# iter 3
# 100/1000
# iter 4
# 100/1000
# iter 5
# 100/1000
# iter 6
# 100/1000
# iter 7
# 100/1000
# iter 8
# 100/1000
# iter 9
# 100/1000
# iter 10
# 100/1000
# iter 11
# 100/1000
# iter 12
# 100/1000
# iter 13
# 100/1000
# iter 14
# 100/1000
# iter 15
# 100/1000
# iter 16
# 100/1000
# iter 17
# 100/1000
# iter 18
# 100/1000
# iter 19
# 100/1000
# iter 20
# 100/1000
# iter 21
# 100/1000
# iter 22
# 100/1000
# iter 23
# 100/1000
# iter 24
# 100/1000
# iter 25
# 100/1000
# iter 26
# 100/1000
# iter 27
# 100/1000
# iter 28
# 100/1000
# iter 29
# 100/1000
# iter 30
# 100/1000
# iter 31
# 100/1000
# iter 32
# 100/1000
# iter 33
# 100/1000
# iter 34
# 100/1000
# iter 35
# 100/1000
# iter 36
# 100/1000
# iter 37
# 100/1000
# iter 38
# 100/1000
# iter 39
# 100/1000
# iter 40
# 100/1000
# iter 41
# 100/1000
# iter 42
# 100/1000
# iter 43
# 100/1000
# iter 44
# 100/1000
# iter 45
# 100/1000
# iter 46
# 100/1000
# iter 47
# 100/1000
# iter 48
# 100/1000
# iter 49
# 100/1000
# mean return -491.6221211499258
# std of return 1.7642785377631862
# DAgger iteration  1
# opmization step  0
# obj value is  0.16734919
# opmization step  1000
# obj value is  0.13593802
# opmization step  2000
# obj value is  0.121063225
# opmization step  3000
# obj value is  0.11787951
# opmization step  4000
# obj value is  0.12167976
# opmization step  5000
# obj value is  0.11903883
# opmization step  6000
# obj value is  0.12237806
# opmization step  7000
# obj value is  0.1155114
# opmization step  8000
# obj value is  0.11402716
# opmization step  9000
# obj value is  0.11297956
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return 31.93491252544966
# std of return 0.020383278002262133
# DAgger iteration  2
# opmization step  0
# obj value is  0.11934942
# opmization step  1000
# obj value is  0.11168831
# opmization step  2000
# obj value is  0.11233886
# opmization step  3000
# obj value is  0.11822717
# opmization step  4000
# obj value is  0.11451173
# opmization step  5000
# obj value is  0.114099175
# opmization step  6000
# obj value is  0.11387309
# opmization step  7000
# obj value is  0.11325333
# opmization step  8000
# obj value is  0.1117975
# opmization step  9000
# obj value is  0.16051921
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -265.78148569868375
# std of return 0.0004977830741688649
# DAgger iteration  3
# opmization step  0
# obj value is  0.15347998
# opmization step  1000
# obj value is  0.152844
# opmization step  2000
# obj value is  0.15283218
# opmization step  3000
# obj value is  0.15282167
# opmization step  4000
# obj value is  0.1528425
# opmization step  5000
# obj value is  0.15284298
# opmization step  6000
# obj value is  0.15285823
# opmization step  7000
# obj value is  0.15282796
# opmization step  8000
# obj value is  0.15287629
# opmization step  9000
# obj value is  0.15284677
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -183.067841964323
# std of return 0.0003941915125403738
# DAgger iteration  4
# opmization step  0
# obj value is  0.15052578
# opmization step  1000
# obj value is  0.15033786
# opmization step  2000
# obj value is  0.15032695
# opmization step  3000
# obj value is  0.15033579
# opmization step  4000
# obj value is  0.15031451
# opmization step  5000
# obj value is  0.150335
# opmization step  6000
# obj value is  0.15035869
# opmization step  7000
# obj value is  0.15033989
# opmization step  8000
# obj value is  0.15033314
# opmization step  9000
# obj value is  0.15033439
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -115.87739944669032
# std of return 0.0011206654334006314
# DAgger iteration  5
# opmization step  0
# obj value is  0.14839014
# opmization step  1000
# obj value is  0.14834403
# opmization step  2000
# obj value is  0.1483326
# opmization step  3000
# obj value is  0.14832221
# opmization step  4000
# obj value is  0.14833358
# opmization step  5000
# obj value is  0.14834353
# opmization step  6000
# obj value is  0.14840727
# opmization step  7000
# obj value is  0.14834668
# opmization step  8000
# obj value is  0.14834861
# opmization step  9000
# obj value is  0.14836459
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -118.07495549493991
# std of return 0.0003198963371690411
# DAgger iteration  6
# opmization step  0
# obj value is  0.14717108
# opmization step  1000
# obj value is  0.14712189
# opmization step  2000
# obj value is  0.14712404
# opmization step  3000
# obj value is  0.14711493
# opmization step  4000
# obj value is  0.14708138
# opmization step  5000
# obj value is  0.14708403
# opmization step  6000
# obj value is  0.14711241
# opmization step  7000
# obj value is  0.14710201
# opmization step  8000
# obj value is  0.14708243
# opmization step  9000
# obj value is  0.14714794
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -119.9942287588177
# std of return 0.00023707041832608417
# DAgger iteration  7
# opmization step  0
# obj value is  0.1461052
# opmization step  1000
# obj value is  0.14602609
# opmization step  2000
# obj value is  0.14608276
# opmization step  3000
# obj value is  0.14603533
# opmization step  4000
# obj value is  0.14612569
# opmization step  5000
# obj value is  0.14605878
# opmization step  6000
# obj value is  0.14603573
# opmization step  7000
# obj value is  0.14605393
# opmization step  8000
# obj value is  0.14606977
# opmization step  9000
# obj value is  0.14613385
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -108.71809975642041
# std of return 0.00043228648296690165
# DAgger iteration  8
# opmization step  0
# obj value is  0.14482588
# opmization step  1000
# obj value is  0.14489457
# opmization step  2000
# obj value is  0.14478984
# opmization step  3000
# obj value is  0.1447863
# opmization step  4000
# obj value is  0.14480571
# opmization step  5000
# obj value is  0.14477748
# opmization step  6000
# obj value is  0.14481238
# opmization step  7000
# obj value is  0.14479972
# opmization step  8000
# obj value is  0.14478539
# opmization step  9000
# obj value is  0.14477889
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -90.54005604759713
# std of return 5.3923482681739194e-05
# DAgger iteration  9
# opmization step  0
# obj value is  0.14358637
# opmization step  1000
# obj value is  0.14360948
# opmization step  2000
# obj value is  0.14358068
# opmization step  3000
# obj value is  0.14359654
# opmization step  4000
# obj value is  0.14360303
# opmization step  5000
# obj value is  0.1436272
# opmization step  6000
# obj value is  0.14366557
# opmization step  7000
# obj value is  0.14367828
# opmization step  8000
# obj value is  0.14362237
# opmization step  9000
# obj value is  0.14359288
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -91.12561251972777
# std of return 9.995313558050609e-05
# DAgger iteration  10
# opmization step  0
# obj value is  0.1425497
# opmization step  1000
# obj value is  0.14251322
# opmization step  2000
# obj value is  0.1425986
# opmization step  3000
# obj value is  0.1425386
# opmization step  4000
# obj value is  0.14254507
# opmization step  5000
# obj value is  0.14257018
# opmization step  6000
# obj value is  0.14253172
# opmization step  7000
# obj value is  0.1425466
# opmization step  8000
# obj value is  0.14252645
# opmization step  9000
# obj value is  0.14252147
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -85.84051064827807
# std of return 0.00013685611490274143
# DAgger iteration  11
# opmization step  0
# obj value is  0.14140719
# opmization step  1000
# obj value is  0.14143825
# opmization step  2000
# obj value is  0.14149009
# opmization step  3000
# obj value is  0.14141823
# opmization step  4000
# obj value is  0.14138164
# opmization step  5000
# obj value is  0.14141445
# opmization step  6000
# obj value is  0.14141372
# opmization step  7000
# obj value is  0.14142698
# opmization step  8000
# obj value is  0.14141494
# opmization step  9000
# obj value is  0.14139655
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -79.37616428945655
# std of return 4.802489752108841e-05
# DAgger iteration  12
# opmization step  0
# obj value is  0.14051615
# opmization step  1000
# obj value is  0.14049171
# opmization step  2000
# obj value is  0.14051527
# opmization step  3000
# obj value is  0.14053869
# opmization step  4000
# obj value is  0.1405145
# opmization step  5000
# obj value is  0.14049038
# opmization step  6000
# obj value is  0.14047992
# opmization step  7000
# obj value is  0.14052318
# opmization step  8000
# obj value is  0.14050733
# opmization step  9000
# obj value is  0.1404763
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -70.60227160609887
# std of return 0.00025722688227006077
# DAgger iteration  13
# opmization step  0
# obj value is  0.13989608
# opmization step  1000
# obj value is  0.1398165
# opmization step  2000
# obj value is  0.13982849
# opmization step  3000
# obj value is  0.13982248
# opmization step  4000
# obj value is  0.1398476
# opmization step  5000
# obj value is  0.13982518
# opmization step  6000
# obj value is  0.13981797
# opmization step  7000
# obj value is  0.13983268
# opmization step  8000
# obj value is  0.13981631
# opmization step  9000
# obj value is  0.13983895
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -93.03111653959805
# std of return 2.9003920735419795e-05
# DAgger iteration  14
# opmization step  0
# obj value is  0.1390869
# opmization step  1000
# obj value is  0.13907935
# opmization step  2000
# obj value is  0.1391181
# opmization step  3000
# obj value is  0.13904834
# opmization step  4000
# obj value is  0.13906927
# opmization step  5000
# obj value is  0.13906488
# opmization step  6000
# obj value is  0.13905135
# opmization step  7000
# obj value is  0.1390439
# opmization step  8000
# obj value is  0.13904181
# opmization step  9000
# obj value is  0.13905953
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -87.9570288529386
# std of return 0.0003982632614255975
# DAgger iteration  15
# opmization step  0
# obj value is  0.1381266
# opmization step  1000
# obj value is  0.13804464
# opmization step  2000
# obj value is  0.13808887
# opmization step  3000
# obj value is  0.13809443
# opmization step  4000
# obj value is  0.138087
# opmization step  5000
# obj value is  0.13805304
# opmization step  6000
# obj value is  0.13805224
# opmization step  7000
# obj value is  0.13809945
# opmization step  8000
# obj value is  0.13806272
# opmization step  9000
# obj value is  0.13806799
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -100.67988731886321
# std of return 0.000128814248958804
# DAgger iteration  16
# opmization step  0
# obj value is  0.13722676
# opmization step  1000
# obj value is  0.13720636
# opmization step  2000
# obj value is  0.13725394
# opmization step  3000
# obj value is  0.13721083
# opmization step  4000
# obj value is  0.13719673
# opmization step  5000
# obj value is  0.13719307
# opmization step  6000
# obj value is  0.13724194
# opmization step  7000
# obj value is  0.13720897
# opmization step  8000
# obj value is  0.1372113
# opmization step  9000
# obj value is  0.13719088
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -80.13797023373048
# std of return 8.947920580112622e-05
# DAgger iteration  17
# opmization step  0
# obj value is  0.13652967
# opmization step  1000
# obj value is  0.13656326
# opmization step  2000
# obj value is  0.1365135
# opmization step  3000
# obj value is  0.13658842
# opmization step  4000
# obj value is  0.13652474
# opmization step  5000
# obj value is  0.13657399
# opmization step  6000
# obj value is  0.1365213
# opmization step  7000
# obj value is  0.1365188
# opmization step  8000
# obj value is  0.13653497
# opmization step  9000
# obj value is  0.13651761
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -79.36229716313429
# std of return 0.00040256686630186784
# DAgger iteration  18
# opmization step  0
# obj value is  0.13584068
# opmization step  1000
# obj value is  0.13586174
# opmization step  2000
# obj value is  0.13585833
# opmization step  3000
# obj value is  0.13586888
# opmization step  4000
# obj value is  0.13590348
# opmization step  5000
# obj value is  0.13589622
# opmization step  6000
# obj value is  0.13585448
# opmization step  7000
# obj value is  0.13585049
# opmization step  8000
# obj value is  0.13584393
# opmization step  9000
# obj value is  0.13586308
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -86.3493285079558
# std of return 0.00012010398130598788
# DAgger iteration  19
# opmization step  0
# obj value is  0.13498951
# opmization step  1000
# obj value is  0.1350333
# opmization step  2000
# obj value is  0.13504675
# opmization step  3000
# obj value is  0.13502197
# opmization step  4000
# obj value is  0.13500422
# opmization step  5000
# obj value is  0.13507824
# opmization step  6000
# obj value is  0.13503003
# opmization step  7000
# obj value is  0.13510315
# opmization step  8000
# obj value is  0.13502267
# opmization step  9000
# obj value is  0.13502143
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -80.12445031266866
# std of return 0.00047336442832971663
# DAgger iteration  20
# opmization step  0
# obj value is  0.13426484
# opmization step  1000
# obj value is  0.13434853
# opmization step  2000
# obj value is  0.13426577
# opmization step  3000
# obj value is  0.13429765
# opmization step  4000
# obj value is  0.1342681
# opmization step  5000
# obj value is  0.13425802
# opmization step  6000
# obj value is  0.13432388
# opmization step  7000
# obj value is  0.13427638
# opmization step  8000
# obj value is  0.13427779
# opmization step  9000
# obj value is  0.13429032
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -72.40265050558156
# std of return 0.000393883048654402
# DAgger iteration  21
# opmization step  0
# obj value is  0.13349377
# opmization step  1000
# obj value is  0.13349374
# opmization step  2000
# obj value is  0.1335087
# opmization step  3000
# obj value is  0.13352485
# opmization step  4000
# obj value is  0.13347186
# opmization step  5000
# obj value is  0.13347657
# opmization step  6000
# obj value is  0.13342403
# opmization step  7000
# obj value is  0.13349143
# opmization step  8000
# obj value is  0.13356823
# opmization step  9000
# obj value is  0.1334413
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -101.72006595194176
# std of return 0.00014436757787166237
# DAgger iteration  22
# opmization step  0
# obj value is  0.13282081
# opmization step  1000
# obj value is  0.13278991
# opmization step  2000
# obj value is  0.13280696
# opmization step  3000
# obj value is  0.13279456
# opmization step  4000
# obj value is  0.13271378
# opmization step  5000
# obj value is  0.13279502
# opmization step  6000
# obj value is  0.13276233
# opmization step  7000
# obj value is  0.13287653
# opmization step  8000
# obj value is  0.13275558
# opmization step  9000
# obj value is  0.1327787
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -103.24064043063278
# std of return 0.0002878090683981327
# DAgger iteration  23
# opmization step  0
# obj value is  0.13202305
# opmization step  1000
# obj value is  0.13197057
# opmization step  2000
# obj value is  0.13197657
# opmization step  3000
# obj value is  0.13195199
# opmization step  4000
# obj value is  0.13194056
# opmization step  5000
# obj value is  0.13196813
# opmization step  6000
# obj value is  0.13196011
# opmization step  7000
# obj value is  0.13201162
# opmization step  8000
# obj value is  0.1319606
# opmization step  9000
# obj value is  0.13203003
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -81.51670367094836
# std of return 0.0003043761471857919
# DAgger iteration  24
# opmization step  0
# obj value is  0.13136393
# opmization step  1000
# obj value is  0.13140789
# opmization step  2000
# obj value is  0.13139041
# opmization step  3000
# obj value is  0.13139386
# opmization step  4000
# obj value is  0.13140723
# opmization step  5000
# obj value is  0.13140531
# opmization step  6000
# obj value is  0.13142097
# opmization step  7000
# obj value is  0.13135985
# opmization step  8000
# obj value is  0.1313985
# opmization step  9000
# obj value is  0.13137685
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -81.43737047803747
# std of return 0.00022194601709117021
# DAgger iteration  25
# opmization step  0
# obj value is  0.13065751
# opmization step  1000
# obj value is  0.1306978
# opmization step  2000
# obj value is  0.13064903
# opmization step  3000
# obj value is  0.1306483
# opmization step  4000
# obj value is  0.13073204
# opmization step  5000
# obj value is  0.13064723
# opmization step  6000
# obj value is  0.13072999
# opmization step  7000
# obj value is  0.13067898
# opmization step  8000
# obj value is  0.13064872
# opmization step  9000
# obj value is  0.1306575
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -71.21224991251091
# std of return 0.00014245236797052032
# DAgger iteration  26
# opmization step  0
# obj value is  0.1301033
# opmization step  1000
# obj value is  0.130133
# opmization step  2000
# obj value is  0.13013017
# opmization step  3000
# obj value is  0.13006365
# opmization step  4000
# obj value is  0.13010415
# opmization step  5000
# obj value is  0.13011006
# opmization step  6000
# obj value is  0.13008569
# opmization step  7000
# obj value is  0.13009627
# opmization step  8000
# obj value is  0.13017072
# opmization step  9000
# obj value is  0.13007224
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -82.37403517393453
# std of return 0.000361450379793098
# DAgger iteration  27
# opmization step  0
# obj value is  0.12933426
# opmization step  1000
# obj value is  0.12937
# opmization step  2000
# obj value is  0.129377
# opmization step  3000
# obj value is  0.12938055
# opmization step  4000
# obj value is  0.12936296
# opmization step  5000
# obj value is  0.12935229
# opmization step  6000
# obj value is  0.12935777
# opmization step  7000
# obj value is  0.12937506
# opmization step  8000
# obj value is  0.12938017
# opmization step  9000
# obj value is  0.12934525
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -80.02824365478065
# std of return 1.9231551155485247e-05
# DAgger iteration  28
# opmization step  0
# obj value is  0.12874554
# opmization step  1000
# obj value is  0.12869047
# opmization step  2000
# obj value is  0.12871186
# opmization step  3000
# obj value is  0.12872028
# opmization step  4000
# obj value is  0.12870525
# opmization step  5000
# obj value is  0.12868525
# opmization step  6000
# obj value is  0.12875049
# opmization step  7000
# obj value is  0.12872455
# opmization step  8000
# obj value is  0.128731
# opmization step  9000
# obj value is  0.12874198
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -87.44727045869429
# std of return 0.00013036778822709036
# DAgger iteration  29
# opmization step  0
# obj value is  0.12809674
# opmization step  1000
# obj value is  0.12807624
# opmization step  2000
# obj value is  0.12809373
# opmization step  3000
# obj value is  0.1281041
# opmization step  4000
# obj value is  0.12808636
# opmization step  5000
# obj value is  0.12808831
# opmization step  6000
# obj value is  0.12812066
# opmization step  7000
# obj value is  0.12806973
# opmization step  8000
# obj value is  0.12807041
# opmization step  9000
# obj value is  0.12807767
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -95.73469470589494
# std of return 0.00021275109093579653
# DAgger iteration  30
# opmization step  0
# obj value is  0.1274109
# opmization step  1000
# obj value is  0.12736116
# opmization step  2000
# obj value is  0.12736037
# opmization step  3000
# obj value is  0.12740181
# opmization step  4000
# obj value is  0.12745439
# opmization step  5000
# obj value is  0.12739109
# opmization step  6000
# obj value is  0.12745002
# opmization step  7000
# obj value is  0.12737143
# opmization step  8000
# obj value is  0.12737904
# opmization step  9000
# obj value is  0.12739952
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -88.29840644345764
# std of return 0.000136059645664659
# DAgger iteration  31
# opmization step  0
# obj value is  0.12675874
# opmization step  1000
# obj value is  0.12675603
# opmization step  2000
# obj value is  0.1267687
# opmization step  3000
# obj value is  0.12678212
# opmization step  4000
# obj value is  0.12671164
# opmization step  5000
# obj value is  0.12676603
# opmization step  6000
# obj value is  0.12678695
# opmization step  7000
# obj value is  0.12673616
# opmization step  8000
# obj value is  0.12672454
# opmization step  9000
# obj value is  0.12676175
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -81.82755067602156
# std of return 0.0001518656096948234
# DAgger iteration  32
# opmization step  0
# obj value is  0.12608677
# opmization step  1000
# obj value is  0.12612474
# opmization step  2000
# obj value is  0.12620865
# opmization step  3000
# obj value is  0.12621512
# opmization step  4000
# obj value is  0.12620166
# opmization step  5000
# obj value is  0.12614487
# opmization step  6000
# obj value is  0.1261446
# opmization step  7000
# obj value is  0.1262023
# opmization step  8000
# obj value is  0.12619548
# opmization step  9000
# obj value is  0.12618326
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -87.55287176650336
# std of return 0.0001570697685363598
# DAgger iteration  33
# opmization step  0
# obj value is  0.12551534
# opmization step  1000
# obj value is  0.12551679
# opmization step  2000
# obj value is  0.1255542
# opmization step  3000
# obj value is  0.12545155
# opmization step  4000
# obj value is  0.12557158
# opmization step  5000
# obj value is  0.12550384
# opmization step  6000
# obj value is  0.1255707
# opmization step  7000
# obj value is  0.1255253
# opmization step  8000
# obj value is  0.12549219
# opmization step  9000
# obj value is  0.12548323
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -82.3760752036381
# std of return 6.56641109259226e-05
# DAgger iteration  34
# opmization step  0
# obj value is  0.12486201
# opmization step  1000
# obj value is  0.12491114
# opmization step  2000
# obj value is  0.124846615
# opmization step  3000
# obj value is  0.12484432
# opmization step  4000
# obj value is  0.12485768
# opmization step  5000
# obj value is  0.124909
# opmization step  6000
# obj value is  0.1248801
# opmization step  7000
# obj value is  0.12487033
# opmization step  8000
# obj value is  0.12488263
# opmization step  9000
# obj value is  0.12492853
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46
# iter 47
# iter 48
# iter 49
# mean return -80.91286046893939
# std of return 0.0004206878486010623
# DAgger iteration  35
# opmization step  0
# obj value is  0.124269746
# opmization step  1000
# obj value is  0.1242542
# opmization step  2000
# obj value is  0.124282695
# opmization step  3000
# obj value is  0.12427124
# opmization step  4000
# obj value is  0.124215744
# opmization step  5000
# obj value is  0.124309696
# opmization step  6000
# obj value is  0.12427994
# opmization step  7000
# obj value is  0.12425359
# opmization step  8000
# obj value is  0.12424324
# opmization step  9000
# obj value is  0.12427792
# Optimization Finished!
# iter 0
# iter 1
# iter 2
# iter 3
# iter 4
# iter 5
# iter 6
# iter 7
# iter 8
# iter 9
# iter 10
# iter 11
# iter 12
# iter 13
# iter 14
# iter 15
# iter 16
# iter 17
# iter 18
# iter 19
# iter 20
# iter 21
# iter 22
# iter 23
# iter 24
# iter 25
# iter 26
# iter 27
# iter 28
# iter 29
# iter 30
# iter 31
# iter 32
# iter 33
# iter 34
# iter 35
# iter 36
# iter 37
# iter 38
# iter 39
# iter 40
# iter 41
# iter 42
# iter 43
# iter 44
# iter 45
# iter 46

# %%
# Save the Mean of the Returns.
global_mean_G=np.array(global_mean_G)
np.savetxt('Variables/global_mean_G_epsilon.txt', global_mean_G , fmt='%f')

# %%
plt.plot(global_mean_G)
plt.ylabel('Average of Returns')
plt.xlabel('Number of iterations')
plt.savefig("Plots/Average_of_Returns_iterations_epsilon.png")
